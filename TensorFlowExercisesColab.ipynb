# %% [markdown]
# <a href="https://colab.research.google.com/github/HikmatullahAminy/HelmandKardanManagmentSystem/blob/googleColabProjectsAndExercises/TensorFlowExercisesColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import tensorflow as tf
#
# # Helper libraries
# import numpy as np
# import matplotlib.pyplot as plt

# %% [markdown]
# # New Section

# %%
# TensorFlow and tf.keras
import tensorflow as tf


# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

print(tf.__version__)
# Out:
# 2.14.0

# %% [markdown]
# is it ok now

# %% [markdown]
# # New Section

# %%
data=pd.read_csv("train.csv",",")
data.shape
data.head()
# Out:
# <ipython-input-4-d5f03e6ef76a>:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   data=pd.read_csv("train.csv",",")
#    v.id  on road old  on road now  years      km  rating  condition  economy  \
# 0     1       535651       798186      3   78945       1          2       14
# 1     2       591911       861056      6  117220       5          9        9
# 2     3       686990       770762      2  132538       2          8       15
# 3     4       573999       722381      4  101065       4          3       11
# 4     5       691388       811335      6   61559       3          9       12
#
#    top speed  hp  torque  current price
# 0        177  73     123       351318.0
# 1        148  74      95       285001.5
# 2        181  53      97       215386.0
# 3        197  54     116       244295.5
# 4        160  53     105       531114.5

# %%
sns.pairplot(data[['years','km','rating','economy','top speed','current price']],diag_kind='kde')

# %%
sns.pairplot(data[['v.id','on road old','on road now','years','km','rating', 'condition','economy','top speed','current price']],diag_kind='kde')
